# %% [markdown]
# # POSTGRESQL Database Access
#
# - install `postgres` library: `pip3 install postres`
# - data type references: `https://www.postgresql.org/docs/current/datatype.html`

# %%
import psycopg2
import pandas as pd

# %%
database_host = 'localhost'
database_portno = 5432
schema_name = 'dvdrental'
user = 'postgres'
password = 'password'

# %%
conn = psycopg2.connect(host=database_host, port = database_portno, 
                        database=schema_name, user=user, 
                        password=password)

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:password@localhost:5432/dvdrental')

# %% [markdown]
# # 1. Basic Queries
# The following contains basic SQL commands operate on `dvdrental` database.
#
# You can find more information on these queries here `https://nuitrcs.github.io/databases_workshop/`

# %%
query = 'select * from actor'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#      actor_id first_name     last_name             last_update
# 0           1   Penelope       Guiness 2013-05-26 14:47:57.620
# 1           2       Nick      Wahlberg 2013-05-26 14:47:57.620
# 2           3         Ed         Chase 2013-05-26 14:47:57.620
# 3           4   Jennifer         Davis 2013-05-26 14:47:57.620
# 4           5     Johnny  Lollobrigida 2013-05-26 14:47:57.620
# ..        ...        ...           ...                     ...
# 195       196       Bela        Walken 2013-05-26 14:47:57.620
# 196       197      Reese          West 2013-05-26 14:47:57.620
# 197       198       Mary        Keitel 2013-05-26 14:47:57.620
# 198       199      Julia       Fawcett 2013-05-26 14:47:57.620
# 199       200      Thora        Temple 2013-05-26 14:47:57.620
#
# [200 rows x 4 columns]

# %%
query = 'SELECT customer_id, store_id FROM customer LIMIT 10'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#    customer_id  store_id
# 0          524         1
# 1            1         1
# 2            2         1
# 3            3         1
# 4            4         2
# 5            5         1
# 6            6         2
# 7            7         1
# 8            8         2
# 9            9         2

# %%
query = 'SELECT * FROM customer LIMIT 10'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#    customer_id  store_id first_name last_name  \
# 0          524         1      Jared       Ely
# 1            1         1       Mary     Smith
# 2            2         1   Patricia   Johnson
# 3            3         1      Linda  Williams
# 4            4         2    Barbara     Jones
# 5            5         1  Elizabeth     Brown
# 6            6         2   Jennifer     Davis
# 7            7         1      Maria    Miller
# 8            8         2      Susan    Wilson
# 9            9         2   Margaret     Moore
#
#                                  email  address_id  activebool create_date  \
# 0         jared.ely@sakilacustomer.org         530        True  2006-02-14
# 1        mary.smith@sakilacustomer.org           5        True  2006-02-14
# 2  patricia.johnson@sakilacustomer.org           6        True  2006-02-14
# 3    linda.williams@sakilacustomer.org           7        True  2006-02-14
# 4     barbara.jones@sakilacustomer.org           8        True  2006-02-14
# 5   elizabeth.brown@sakilacustomer.org           9        True  2006-02-14
# 6    jennifer.davis@sakilacustomer.org          10        True  2006-02-14
# 7      maria.miller@sakilacustomer.org          11        True  2006-02-14
# 8      susan.wilson@sakilacustomer.org          12        True  2006-02-14
# 9    margaret.moore@sakilacustomer.org          13        True  2006-02-14
#
#               last_update  active
# 0 2013-05-26 14:49:45.738       1
# 1 2013-05-26 14:49:45.738       1
# 2 2013-05-26 14:49:45.738       1
# 3 2013-05-26 14:49:45.738       1
# 4 2013-05-26 14:49:45.738       1
# 5 2013-05-26 14:49:45.738       1
# 6 2013-05-26 14:49:45.738       1
# 7 2013-05-26 14:49:45.738       1
# 8 2013-05-26 14:49:45.738       1
# 9 2013-05-26 14:49:45.738       1

# %%
query = '\
SELECT customer_id, store_id, first_name, last_name  \
FROM customer \
LIMIT 5 \
OFFSET 10'

df = pd.read_sql_query(query,con=engine)
df
# Out:
#    customer_id  store_id first_name last_name
# 0           10         1    Dorothy    Taylor
# 1           11         2       Lisa  Anderson
# 2           12         1      Nancy    Thomas
# 3           13         2      Karen   Jackson
# 4           14         2      Betty     White

# %% [markdown]
# ## WHERE clause
#
# |Operator | Description|
# | ---: | ---: |
# |= |Equal|
# |> |Greater than|
# |< |Less than|
# |>= |Greater than or equal|
# |<= |Less than or equal|
# |<> or != |Not equal|
# |AND |Logical operator AND|
# |OR |Logical operator OR|
# |NOT |To negate boolean values|

# %%
query = 'SELECT * FROM customer WHERE store_id=2;'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#      customer_id  store_id first_name  last_name  \
# 0              4         2    Barbara      Jones
# 1              6         2   Jennifer      Davis
# 2              8         2      Susan     Wilson
# 3              9         2   Margaret      Moore
# 4             11         2       Lisa   Anderson
# ..           ...       ...        ...        ...
# 268          582         2       Andy    Vanhorn
# 269          584         2   Salvador       Teel
# 270          590         2       Seth     Hannon
# 271          593         2       Rene  Mcalister
# 272          599         2     Austin    Cintron
#
#                                  email  address_id  activebool create_date  \
# 0     barbara.jones@sakilacustomer.org           8        True  2006-02-14
# 1    jennifer.davis@sakilacustomer.org          10        True  2006-02-14
# 2      susan.wilson@sakilacustomer.org          12        True  2006-02-14
# 3    margaret.moore@sakilacustomer.org          13        True  2006-02-14
# 4     lisa.anderson@sakilacustomer.org          15        True  2006-02-14
# ..                                 ...         ...         ...         ...
# 268    andy.vanhorn@sakilacustomer.org         588        True  2006-02-14
# 269   salvador.teel@sakilacustomer.org         590        True  2006-02-14
# 270     seth.hannon@sakilacustomer.org         596        True  2006-02-14
# 271  rene.mcalister@sakilacustomer.org         599        True  2006-02-14
# 272  austin.cintron@sakilacustomer.org         605        True  2006-02-14
#
#                 last_update  active
# 0   2013-05-26 14:49:45.738       1
# 1   2013-05-26 14:49:45.738       1
# 2   2013-05-26 14:49:45.738       1
# 3   2013-05-26 14:49:45.738       1
# 4   2013-05-26 14:49:45.738       1
# ..                      ...     ...
# 268 2013-05-26 14:49:45.738       1
# 269 2013-05-26 14:49:45.738       1
# 270 2013-05-26 14:49:45.738       1
# 271 2013-05-26 14:49:45.738       1
# 272 2013-05-26 14:49:45.738       1
#
# [273 rows x 10 columns]

# %%
query = 'SELECT * FROM customer WHERE store_id=2 AND customer_id=400;'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#    customer_id  store_id first_name last_name  \
# 0          400         2      Bryan  Hardison
#
#                                email  address_id  activebool create_date  \
# 0  bryan.hardison@sakilacustomer.org         405        True  2006-02-14
#
#               last_update  active
# 0 2013-05-26 14:49:45.738       1

# %%
query = "SELECT * FROM staff WHERE first_name='Jon';"
df = pd.read_sql_query(query,con=engine)
df
# Out:
#    staff_id first_name last_name  address_id                         email  \
# 0         2        Jon  Stephens           4  Jon.Stephens@sakilastaff.com
#
#    store_id  active username                                  password  \
# 0         2    True      Jon  8cb2237d0679ca88db6464eac60da96345513964
#
#                  last_update picture
# 0 2006-05-16 16:13:11.793280    None

# %%
query = "SELECT * FROM staff where first_name != 'Jon';"
df = pd.read_sql_query(query,con=engine)
df
# Out:
#    staff_id first_name last_name  address_id                         email  \
# 0         1       Mike   Hillyer           3  Mike.Hillyer@sakilastaff.com
#
#    store_id  active username                                  password  \
# 0         1    True     Mike  8cb2237d0679ca88db6464eac60da96345513964
#
#                  last_update  \
# 0 2006-05-16 16:13:11.793280
#
#                                              picture
# 0  [b'\x89', b'P', b'N', b'G', b'\r', b'\n', b'Z'...

# %%
query = "SELECT * FROM staff where first_name <> 'Jon';"
df = pd.read_sql_query(query,con=engine)
df
# Out:
#    staff_id first_name last_name  address_id                         email  \
# 0         1       Mike   Hillyer           3  Mike.Hillyer@sakilastaff.com
#
#    store_id  active username                                  password  \
# 0         1    True     Mike  8cb2237d0679ca88db6464eac60da96345513964
#
#                  last_update  \
# 0 2006-05-16 16:13:11.793280
#
#                                              picture
# 0  [b'\x89', b'P', b'N', b'G', b'\r', b'\n', b'Z'...

# %%
query = 'SELECT * FROM film WHERE film_id BETWEEN 1 AND 5;'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#    film_id             title  \
# 0        1  Academy Dinosaur
# 1        2    Ace Goldfinger
# 2        3  Adaptation Holes
# 3        4  Affair Prejudice
# 4        5       African Egg
#
#                                          description  release_year  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1  A Astounding Epistle of a Database Administrat...          2006
# 2  A Astounding Reflection of a Lumberjack And a ...          2006
# 3  A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4  A Fast-Paced Documentary of a Pastry Chef And ...          2006
#
#    language_id  rental_duration  rental_rate  length  replacement_cost rating  \
# 0            1                6         0.99      86             20.99     PG
# 1            1                3         4.99      48             12.99      G
# 2            1                7         2.99      50             18.99  NC-17
# 3            1                5         2.99     117             26.99      G
# 4            1                6         2.99     130             22.99      G
#
#               last_update                     special_features  \
# 0 2013-05-26 14:50:58.951  [Deleted Scenes, Behind the Scenes]
# 1 2013-05-26 14:50:58.951           [Trailers, Deleted Scenes]
# 2 2013-05-26 14:50:58.951           [Trailers, Deleted Scenes]
# 3 2013-05-26 14:50:58.951    [Commentaries, Behind the Scenes]
# 4 2013-05-26 14:50:58.951                     [Deleted Scenes]
#
#                                             fulltext
# 0  'academi':1 'battl':15 'canadian':20 'dinosaur...
# 1  'ace':1 'administr':9 'ancient':19 'astound':4...
# 2  'adapt':1 'astound':4 'baloon':19 'car':11 'fa...
# 3  'affair':1 'chase':14 'documentari':5 'fanci':...
# 4  'african':1 'chef':11 'dentist':14 'documentar...

# %%
query = 'SELECT * FROM film WHERE film_id IN (3,5,7,9);'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#    film_id             title  \
# 0        3  Adaptation Holes
# 1        5       African Egg
# 2        7   Airplane Sierra
# 3        9     Alabama Devil
#
#                                          description  release_year  \
# 0  A Astounding Reflection of a Lumberjack And a ...          2006
# 1  A Fast-Paced Documentary of a Pastry Chef And ...          2006
# 2  A Touching Saga of a Hunter And a Butler who m...          2006
# 3  A Thoughtful Panorama of a Database Administra...          2006
#
#    language_id  rental_duration  rental_rate  length  replacement_cost rating  \
# 0            1                7         2.99      50             18.99  NC-17
# 1            1                6         2.99     130             22.99      G
# 2            1                6         4.99      62             28.99  PG-13
# 3            1                3         2.99     114             21.99  PG-13
#
#               last_update            special_features  \
# 0 2013-05-26 14:50:58.951  [Trailers, Deleted Scenes]
# 1 2013-05-26 14:50:58.951            [Deleted Scenes]
# 2 2013-05-26 14:50:58.951  [Trailers, Deleted Scenes]
# 3 2013-05-26 14:50:58.951  [Trailers, Deleted Scenes]
#
#                                             fulltext
# 0  'adapt':1 'astound':4 'baloon':19 'car':11 'fa...
# 1  'african':1 'chef':11 'dentist':14 'documentar...
# 2  'airplan':1 'boat':20 'butler':11,16 'discov':...
# 3  'administr':9 'alabama':1 'boat':23 'databas':...

# %%
query = 'SELECT * FROM address WHERE address2 IS NULL;'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#    address_id               address address2 district  city_id postal_code  \
# 0           1     47 MySakila Drive     None  Alberta      300
# 1           2    28 MySQL Boulevard     None      QLD      576
# 2           3     23 Workhaven Lane     None  Alberta      300
# 3           4  1411 Lillydale Drive     None      QLD      576
#
#          phone         last_update
# 0              2006-02-15 09:45:30
# 1              2006-02-15 09:45:30
# 2  14033335568 2006-02-15 09:45:30
# 3   6172235589 2006-02-15 09:45:30

# %%
# Null is not same as '' (empty)
query = "SELECT * FROM address WHERE address2 = '';"
df = pd.read_sql_query(query,con=engine)
df
# Out:
#      address_id                   address address2      district  city_id  \
# 0             5            1913 Hanoi Way               Nagasaki      463
# 1             6          1121 Loja Avenue             California      449
# 2             7         692 Joliet Street                 Attika       38
# 3             8          1566 Inegl Manor               Mandalay      349
# 4             9           53 Idfu Parkway                 Nantou      361
# ..          ...                       ...      ...           ...      ...
# 594         601       844 Bucuresti Place               Liaoning      242
# 595         602  1101 Bucuresti Boulevard            West Greece      401
# 596         603    1103 Quilmes Boulevard                  Piura      503
# 597         604       1331 Usak Boulevard                   Vaud      296
# 598         605      1325 Fukuyama Street           Heilongjiang      537
#
#     postal_code         phone         last_update
# 0         35200   28303384290 2006-02-15 09:45:30
# 1         17886  838635286649 2006-02-15 09:45:30
# 2         83579  448477190408 2006-02-15 09:45:30
# 3         53561  705814003527 2006-02-15 09:45:30
# 4         42399   10655648674 2006-02-15 09:45:30
# ..          ...           ...                 ...
# 594       36603  935952366111 2006-02-15 09:45:30
# 595       97661  199514580428 2006-02-15 09:45:30
# 596       52137  644021380889 2006-02-15 09:45:30
# 597       61960  145308717464 2006-02-15 09:45:30
# 598       27107  288241215394 2006-02-15 09:45:30
#
# [599 rows x 8 columns]

# %% [markdown]
# ## ORDER BY
# The following queries involved `ORDER BY` predicate.

# %%
query = 'SELECT film_id, title FROM film ORDER BY film_id LIMIT 10'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#    film_id             title
# 0        1  Academy Dinosaur
# 1        2    Ace Goldfinger
# 2        3  Adaptation Holes
# 3        4  Affair Prejudice
# 4        5       African Egg
# 5        6      Agent Truman
# 6        7   Airplane Sierra
# 7        8   Airport Pollock
# 8        9     Alabama Devil
# 9       10  Aladdin Calendar

# %%
query = 'SELECT film_id, title FROM film ORDER BY film_id DESC LIMIT 10'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#    film_id              title
# 0     1000          Zorro Ark
# 1      999  Zoolander Fiction
# 2      998       Zhivago Core
# 3      997         Youth Kick
# 4      996     Young Language
# 5      995        Yentl Idaho
# 6      994      Wyoming Storm
# 7      993     Wrong Behavior
# 8      992         Wrath Mile
# 9      991       Worst Banger

# %%
query = 'SELECT film_id, title FROM film ORDER BY film_id DESC LIMIT 10 OFFSET 11'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#    film_id                 title
# 0      989   Working Microcosmos
# 1      988         Worker Tarzan
# 2      987          Words Hunter
# 3      986             Wonka Sea
# 4      985  Wonderland Christmas
# 5      984        Wonderful Drop
# 6      983             Won Dares
# 7      982          Women Dorado
# 8      981         Wolves Desire
# 9      980    Wizard Coldblooded

# %%
query = '\
SELECT customer_id, rental_id \
FROM rental \
ORDER BY customer_id, rental_id '
df = pd.read_sql_query(query,con=engine)
df
# Out:
#        customer_id  rental_id
# 0                1         76
# 1                1        573
# 2                1       1185
# 3                1       1422
# 4                1       1476
# ...            ...        ...
# 16039          599      14599
# 16040          599      14719
# 16041          599      15590
# 16042          599      15719
# 16043          599      15725
#
# [16044 rows x 2 columns]

# %% [markdown]
# ## DISTINCT
# The following queries involved `DISTINCT` predicates

# %%
query = 'SELECT DISTINCT customer_id, staff_id FROM payment'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#       customer_id  staff_id
# 0             448         2
# 1             459         1
# 2             460         1
# 3             236         2
# 4             282         2
# ...           ...       ...
# 1193          233         2
# 1194           16         2
# 1195          562         1
# 1196          578         1
# 1197          429         2
#
# [1198 rows x 2 columns]

# %%
query = 'SELECT DISTINCT amount FROM payment ORDER BY amount'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#     amount
# 0     0.00
# 1     0.99
# 2     1.98
# 3     1.99
# 4     2.99
# 5     3.98
# 6     3.99
# 7     4.99
# 8     5.98
# 9     5.99
# 10    6.99
# 11    7.98
# 12    7.99
# 13    8.97
# 14    8.99
# 15    9.98
# 16    9.99
# 17   10.99
# 18   11.99

# %% [markdown]
# ## Arithmatic functions
# The following queries involved with built-in `arithmatic` functions.

# %%
query = 'SELECT min(amount) FROM payment;'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#    min
# 0  0.0

# %%
query = 'SELECT max(amount) FROM payment'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#      max
# 0  11.99

# %%
query = 'SELECT max(amount) FROM payment WHERE amount < 4;'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#     max
# 0  3.99

# %%
query = '\
SELECT rental_duration, rental_duration + 1 as next_rental_duration \
FROM film LIMIT 10'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#    rental_duration  next_rental_duration
# 0                7                     8
# 1                5                     6
# 2                6                     7
# 3                4                     5
# 4                6                     7
# 5                3                     4
# 6                7                     8
# 7                5                     6
# 8                6                     7
# 9                3                     4

# %%
query = 'SELECT count(distinct postal_code) from address;'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#    count
# 0    597

# %%
query = 'SELECT count(address2) from address'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#    count
# 0    599

# %%
query = 'SELECT count(*) from address'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#    count
# 0    603

# %%
query = 'SELECT DISTINCT address2 from address'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#   address2
# 0
# 1     None

# %%
query = 'SELECT count(DISTINCT address2) from address'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#    count
# 0      1

# %% [markdown]
# ## GROUP BY
# The following queries uses `GROUP BY` predicate

# %%
query = 'SELECT customer_id, count(*) FROM rental GROUP BY customer_id;'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#      customer_id  count
# 0             87     30
# 1            184     23
# 2            477     22
# 3            273     35
# 4            550     32
# ..           ...    ...
# 594          449     20
# 595          520     32
# 596           64     33
# 597           55     22
# 598          148     46
#
# [599 rows x 2 columns]

# %%
query = 'SELECT customer_id, avg(amount) FROM payment GROUP BY customer_id;'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#      customer_id       avg
# 0            184  4.040000
# 1             87  4.918571
# 2            477  5.085238
# 3            273  4.668571
# 4            550  4.893226
# ..           ...       ...
# 594          449  4.754706
# 595           64  3.056667
# 596          520  4.119032
# 597           55  4.463684
# 598          148  4.701111
#
# [599 rows x 2 columns]

# %%
query = '\
SELECT customer_id, amount, count(*) \
FROM payment \
GROUP BY customer_id, amount;'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#       customer_id  amount  count
# 0              50    7.99      2
# 1             434    7.99      3
# 2              10    0.99      4
# 3             349    0.99      3
# 4             563    6.99      2
# ...           ...     ...    ...
# 4672          443    9.99      1
# 4673          486    8.99      1
# 4674          581    3.99      1
# 4675          568    6.99      1
# 4676          291    3.99      2
#
# [4677 rows x 3 columns]

# %%
query = '\
SELECT customer_id, amount, count(*) FROM payment \
GROUP BY customer_id, amount \
ORDER BY customer_id, count(*) DESC;'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#       customer_id  amount  count
# 0               1    0.99      8
# 1               1    4.99      8
# 2               1    2.99      5
# 3               1    5.99      4
# 4               1    3.99      2
# ...           ...     ...    ...
# 4672          599    4.99      2
# 4673          599    9.99      1
# 4674          599    0.99      1
# 4675          599    3.99      1
# 4676          599    8.99      1
#
# [4677 rows x 3 columns]

# %% [markdown]
# ## HAVING
# HAVING is similar to a WHERE clause but it applies to the result of a GROUP BY operation; WHERE applies before data are grouped by GROUP BY;

# %%
query = '\
SELECT customer_id, sum(amount) \
FROM payment \
GROUP BY customer_id;'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#      customer_id     sum
# 0            184   80.80
# 1             87  137.72
# 2            477  106.79
# 3            273  130.72
# 4            550  151.69
# ..           ...     ...
# 594          449   80.83
# 595           64   91.70
# 596          520  127.69
# 597           55   84.81
# 598          148  211.55
#
# [599 rows x 2 columns]

# %%
query = '\
SELECT customer_id, sum(amount) \
FROM payment \
GROUP BY customer_id \
HAVING sum(amount) > 200;'

df = pd.read_sql_query(query,con=engine)
df
# Out:
#    customer_id     sum
# 0          526  208.58
# 1          148  211.55

# %% [markdown]
# ## DATE:

# %%
query = "\
SELECT count(*) \
FROM customer \
WHERE create_date = '2006-02-14';"

df = pd.read_sql_query(query,con=engine)
df
# Out:
#    count
# 0    599

# %%
query = "\
SELECT rental_date \
FROM rental \
WHERE rental_date < '2005-05-25';"
df = pd.read_sql_query(query,con=engine)
df
# Out:
#           rental_date
# 0 2005-05-24 22:53:30
# 1 2005-05-24 22:54:33
# 2 2005-05-24 23:03:39
# 3 2005-05-24 23:04:41
# 4 2005-05-24 23:05:21
# 5 2005-05-24 23:08:07
# 6 2005-05-24 23:11:53
# 7 2005-05-24 23:31:46

# %%
# Note that you want to use > or < with timestamps, because date equality for just the date part doesn’t work:
query = "\
SELECT rental_date \
FROM rental \
WHERE rental_date = '2005-05-24';"
df = pd.read_sql_query(query,con=engine)
df
# Out:
# Empty DataFrame
# Columns: [rental_date]
# Index: []

# %% [markdown]
# ## ALIAS:

# %%
query = '\
SELECT language_id, count(*) AS c1 \
FROM film \
GROUP BY language_id;'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#    language_id    c1
# 0            1  1000

# %%
query = "\
SELECT title, rating AS rate \
FROM film \
WHERE rating = 'G';"
df = pd.read_sql_query(query,con=engine)
df
# Out:
#                       title rate
# 0            Ace Goldfinger    G
# 1          Affair Prejudice    G
# 2               African Egg    G
# 3           Alamo Videotape    G
# 4         Amistad Midsummer    G
# ..                      ...  ...
# 173  Waterfront Deliverance    G
# 174      Watership Frontier    G
# 175           Werewolf Lola    G
# 176               West Lion    G
# 177          Young Language    G
#
# [178 rows x 2 columns]

# %% [markdown]
# ## SUBQUERIES

# %%
query = "SELECT avg(rental_rate) FROM film;"
df = pd.read_sql_query(query,con=engine)
df
# Out:
#     avg
# 0  2.98

# %%
query = "\
SELECT title, rental_rate FROM film \
WHERE rental_rate < (SELECT avg(rental_rate) FROM film) \
ORDER BY rental_rate DESC;"
df = pd.read_sql_query(query,con=engine)
df
# Out:
#                   title  rental_rate
# 0      Academy Dinosaur         0.99
# 1       Alamo Videotape         0.99
# 2        Alaska Phantom         0.99
# 3            Date Speed         0.99
# 4        Alice Fantasia         0.99
# ..                  ...          ...
# 336  World Leathernecks         0.99
# 337          Wrath Mile         0.99
# 338      Young Language         0.99
# 339          Youth Kick         0.99
# 340        Zhivago Core         0.99
#
# [341 rows x 2 columns]

# %%
query = "\
SELECT * FROM customer \
WHERE address_id IN (SELECT address_id FROM address WHERE postal_code = '52137');"
df = pd.read_sql_query(query,con=engine)
df
# Out:
#    customer_id  store_id first_name last_name  \
# 0          299         2      James    Gannon
# 1          597         1    Freddie    Duggan
#
#                                email  address_id  activebool create_date  \
# 0    james.gannon@sakilacustomer.org         304        True  2006-02-14
# 1  freddie.duggan@sakilacustomer.org         603        True  2006-02-14
#
#               last_update  active
# 0 2013-05-26 14:49:45.738       1
# 1 2013-05-26 14:49:45.738       1

# %%
query = "\
SELECT count(customer_id) FROM \
(SELECT customer_id, count(*) \
 FROM rental GROUP BY customer_id \
 HAVING count(*) > 30) AS foo;"
df = pd.read_sql_query(query,con=engine)
df
# Out:
#    count
# 0    134

# %% [markdown]
# ## INNER JOIN

# %%
query = "\
SELECT * FROM customer \
INNER JOIN address \
ON customer.address_id = address.address_id"
df = pd.read_sql_query(query,con=engine)
df
# Out:
#      customer_id  store_id first_name  last_name  \
# 0            524         1      Jared        Ely
# 1              1         1       Mary      Smith
# 2              2         1   Patricia    Johnson
# 3              3         1      Linda   Williams
# 4              4         2    Barbara      Jones
# ..           ...       ...        ...        ...
# 594          595         1   Terrence  Gunderson
# 595          596         1    Enrique   Forsythe
# 596          597         1    Freddie     Duggan
# 597          598         1       Wade   Delvalle
# 598          599         2     Austin    Cintron
#
#                                      email  address_id  activebool  \
# 0             jared.ely@sakilacustomer.org         530        True
# 1            mary.smith@sakilacustomer.org           5        True
# 2      patricia.johnson@sakilacustomer.org           6        True
# 3        linda.williams@sakilacustomer.org           7        True
# 4         barbara.jones@sakilacustomer.org           8        True
# ..                                     ...         ...         ...
# 594  terrence.gunderson@sakilacustomer.org         601        True
# 595    enrique.forsythe@sakilacustomer.org         602        True
# 596      freddie.duggan@sakilacustomer.org         603        True
# 597       wade.delvalle@sakilacustomer.org         604        True
# 598      austin.cintron@sakilacustomer.org         605        True
#
#     create_date             last_update  active  address_id  \
# 0    2006-02-14 2013-05-26 14:49:45.738       1         530
# 1    2006-02-14 2013-05-26 14:49:45.738       1           5
# 2    2006-02-14 2013-05-26 14:49:45.738       1           6
# 3    2006-02-14 2013-05-26 14:49:45.738       1           7
# 4    2006-02-14 2013-05-26 14:49:45.738       1           8
# ..          ...                     ...     ...         ...
# 594  2006-02-14 2013-05-26 14:49:45.738       1         601
# 595  2006-02-14 2013-05-26 14:49:45.738       1         602
# 596  2006-02-14 2013-05-26 14:49:45.738       1         603
# 597  2006-02-14 2013-05-26 14:49:45.738       1         604
# 598  2006-02-14 2013-05-26 14:49:45.738       1         605
#
#                       address address2      district  city_id postal_code  \
# 0     1003 Qinhuangdao Street              West Java      419       25972
# 1              1913 Hanoi Way               Nagasaki      463       35200
# 2            1121 Loja Avenue             California      449       17886
# 3           692 Joliet Street                 Attika       38       83579
# 4            1566 Inegl Manor               Mandalay      349       53561
# ..                        ...      ...           ...      ...         ...
# 594       844 Bucuresti Place               Liaoning      242       36603
# 595  1101 Bucuresti Boulevard            West Greece      401       97661
# 596    1103 Quilmes Boulevard                  Piura      503       52137
# 597       1331 Usak Boulevard                   Vaud      296       61960
# 598      1325 Fukuyama Street           Heilongjiang      537       27107
#
#             phone         last_update
# 0     35533115997 2006-02-15 09:45:30
# 1     28303384290 2006-02-15 09:45:30
# 2    838635286649 2006-02-15 09:45:30
# 3    448477190408 2006-02-15 09:45:30
# 4    705814003527 2006-02-15 09:45:30
# ..            ...                 ...
# 594  935952366111 2006-02-15 09:45:30
# 595  199514580428 2006-02-15 09:45:30
# 596  644021380889 2006-02-15 09:45:30
# 597  145308717464 2006-02-15 09:45:30
# 598  288241215394 2006-02-15 09:45:30
#
# [599 rows x 18 columns]

# %%
query = "\
SELECT * FROM customer \
INNER JOIN address \
ON customer.address_id = address.address_id \
WHERE postal_code='52137'"
df = pd.read_sql_query(query,con=engine)
df
# Out:
#    customer_id  store_id first_name last_name  \
# 0          299         2      James    Gannon
# 1          597         1    Freddie    Duggan
#
#                                email  address_id  activebool create_date  \
# 0    james.gannon@sakilacustomer.org         304        True  2006-02-14
# 1  freddie.duggan@sakilacustomer.org         603        True  2006-02-14
#
#               last_update  active  address_id                 address  \
# 0 2013-05-26 14:49:45.738       1         304   1635 Kuwana Boulevard
# 1 2013-05-26 14:49:45.738       1         603  1103 Quilmes Boulevard
#
#   address2   district  city_id postal_code         phone         last_update
# 0           Hiroshima      205       52137  710603868323 2006-02-15 09:45:30
# 1               Piura      503       52137  644021380889 2006-02-15 09:45:30

# %%
query = "\
SELECT postal_code, count(*) \
FROM customer \
INNER JOIN address \
ON customer.address_id = address.address_id \
GROUP BY postal_code \
ORDER BY count DESC"
df = pd.read_sql_query(query,con=engine)
df
# Out:
#     postal_code  count
# 0         52137      2
# 1         22474      2
# 2          9668      2
# 3         67912      1
# 4         81766      1
# ..          ...    ...
# 591       69973      1
# 592        1944      1
# 593        9223      1
# 594       53182      1
# 595       15540      1
#
# [596 rows x 2 columns]

# %% [markdown]
# ## Alernative Syntax

# %%
query = "\
SELECT * FROM customer, address \
WHERE customer.address_id = address.address_id;"
df = pd.read_sql_query(query,con=engine)
df
# Out:
#      customer_id  store_id first_name  last_name  \
# 0            524         1      Jared        Ely
# 1              1         1       Mary      Smith
# 2              2         1   Patricia    Johnson
# 3              3         1      Linda   Williams
# 4              4         2    Barbara      Jones
# ..           ...       ...        ...        ...
# 594          595         1   Terrence  Gunderson
# 595          596         1    Enrique   Forsythe
# 596          597         1    Freddie     Duggan
# 597          598         1       Wade   Delvalle
# 598          599         2     Austin    Cintron
#
#                                      email  address_id  activebool  \
# 0             jared.ely@sakilacustomer.org         530        True
# 1            mary.smith@sakilacustomer.org           5        True
# 2      patricia.johnson@sakilacustomer.org           6        True
# 3        linda.williams@sakilacustomer.org           7        True
# 4         barbara.jones@sakilacustomer.org           8        True
# ..                                     ...         ...         ...
# 594  terrence.gunderson@sakilacustomer.org         601        True
# 595    enrique.forsythe@sakilacustomer.org         602        True
# 596      freddie.duggan@sakilacustomer.org         603        True
# 597       wade.delvalle@sakilacustomer.org         604        True
# 598      austin.cintron@sakilacustomer.org         605        True
#
#     create_date             last_update  active  address_id  \
# 0    2006-02-14 2013-05-26 14:49:45.738       1         530
# 1    2006-02-14 2013-05-26 14:49:45.738       1           5
# 2    2006-02-14 2013-05-26 14:49:45.738       1           6
# 3    2006-02-14 2013-05-26 14:49:45.738       1           7
# 4    2006-02-14 2013-05-26 14:49:45.738       1           8
# ..          ...                     ...     ...         ...
# 594  2006-02-14 2013-05-26 14:49:45.738       1         601
# 595  2006-02-14 2013-05-26 14:49:45.738       1         602
# 596  2006-02-14 2013-05-26 14:49:45.738       1         603
# 597  2006-02-14 2013-05-26 14:49:45.738       1         604
# 598  2006-02-14 2013-05-26 14:49:45.738       1         605
#
#                       address address2      district  city_id postal_code  \
# 0     1003 Qinhuangdao Street              West Java      419       25972
# 1              1913 Hanoi Way               Nagasaki      463       35200
# 2            1121 Loja Avenue             California      449       17886
# 3           692 Joliet Street                 Attika       38       83579
# 4            1566 Inegl Manor               Mandalay      349       53561
# ..                        ...      ...           ...      ...         ...
# 594       844 Bucuresti Place               Liaoning      242       36603
# 595  1101 Bucuresti Boulevard            West Greece      401       97661
# 596    1103 Quilmes Boulevard                  Piura      503       52137
# 597       1331 Usak Boulevard                   Vaud      296       61960
# 598      1325 Fukuyama Street           Heilongjiang      537       27107
#
#             phone         last_update
# 0     35533115997 2006-02-15 09:45:30
# 1     28303384290 2006-02-15 09:45:30
# 2    838635286649 2006-02-15 09:45:30
# 3    448477190408 2006-02-15 09:45:30
# 4    705814003527 2006-02-15 09:45:30
# ..            ...                 ...
# 594  935952366111 2006-02-15 09:45:30
# 595  199514580428 2006-02-15 09:45:30
# 596  644021380889 2006-02-15 09:45:30
# 597  145308717464 2006-02-15 09:45:30
# 598  288241215394 2006-02-15 09:45:30
#
# [599 rows x 18 columns]

# %%
query = "\
SELECT * FROM customer, address \
WHERE customer.address_id = address.address_id \
AND postal_code='52137'"
df = pd.read_sql_query(query,con=engine)
df
# Out:
#    customer_id  store_id first_name last_name  \
# 0          299         2      James    Gannon
# 1          597         1    Freddie    Duggan
#
#                                email  address_id  activebool create_date  \
# 0    james.gannon@sakilacustomer.org         304        True  2006-02-14
# 1  freddie.duggan@sakilacustomer.org         603        True  2006-02-14
#
#               last_update  active  address_id                 address  \
# 0 2013-05-26 14:49:45.738       1         304   1635 Kuwana Boulevard
# 1 2013-05-26 14:49:45.738       1         603  1103 Quilmes Boulevard
#
#   address2   district  city_id postal_code         phone         last_update
# 0           Hiroshima      205       52137  710603868323 2006-02-15 09:45:30
# 1               Piura      503       52137  644021380889 2006-02-15 09:45:30

# %%
query = "\
SELECT first_name, last_name, customer.address_id, postal_code  \
FROM customer \
INNER JOIN address \
ON customer.address_id = address.address_id"
df = pd.read_sql_query(query,con=engine)
df
# Out:
#     first_name  last_name  address_id postal_code
# 0        Jared        Ely         530       25972
# 1         Mary      Smith           5       35200
# 2     Patricia    Johnson           6       17886
# 3        Linda   Williams           7       83579
# 4      Barbara      Jones           8       53561
# ..         ...        ...         ...         ...
# 594   Terrence  Gunderson         601       36603
# 595    Enrique   Forsythe         602       97661
# 596    Freddie     Duggan         603       52137
# 597       Wade   Delvalle         604       61960
# 598     Austin    Cintron         605       27107
#
# [599 rows x 4 columns]

# %%
query = "\
SELECT first_name, last_name, c.address_id, postal_code \
FROM customer AS c \
INNER JOIN address AS a \
ON c.address_id = a.address_id"
df = pd.read_sql_query(query,con=engine)
df
# Out:
#     first_name  last_name  address_id postal_code
# 0        Jared        Ely         530       25972
# 1         Mary      Smith           5       35200
# 2     Patricia    Johnson           6       17886
# 3        Linda   Williams           7       83579
# 4      Barbara      Jones           8       53561
# ..         ...        ...         ...         ...
# 594   Terrence  Gunderson         601       36603
# 595    Enrique   Forsythe         602       97661
# 596    Freddie     Duggan         603       52137
# 597       Wade   Delvalle         604       61960
# 598     Austin    Cintron         605       27107
#
# [599 rows x 4 columns]

# %%
query = "\
SELECT first_name, last_name, c.address_id, postal_code \
FROM customer c \
INNER JOIN address a \
ON c.address_id = a.address_id"
df = pd.read_sql_query(query,con=engine)
df
# Out:
#     first_name  last_name  address_id postal_code
# 0        Jared        Ely         530       25972
# 1         Mary      Smith           5       35200
# 2     Patricia    Johnson           6       17886
# 3        Linda   Williams           7       83579
# 4      Barbara      Jones           8       53561
# ..         ...        ...         ...         ...
# 594   Terrence  Gunderson         601       36603
# 595    Enrique   Forsythe         602       97661
# 596    Freddie     Duggan         603       52137
# 597       Wade   Delvalle         604       61960
# 598     Austin    Cintron         605       27107
#
# [599 rows x 4 columns]

# %%
query = "\
SELECT title, first_name, last_name \
FROM film f  \
INNER JOIN film_actor fa ON f.film_id=fa.film_id  \
INNER JOIN actor a ON fa.actor_id=a.actor_id"
df = pd.read_sql_query(query,con=engine)
df
# Out:
#                       title first_name last_name
# 0          Academy Dinosaur   Penelope   Guiness
# 1      Anaconda Confessions   Penelope   Guiness
# 2               Angels Life   Penelope   Guiness
# 3     Bulworth Commandments   Penelope   Guiness
# 4             Cheaper Clyde   Penelope   Guiness
# ...                     ...        ...       ...
# 5457       Telegraph Voyage      Thora    Temple
# 5458        Trojan Tomorrow      Thora    Temple
# 5459        Virginian Pluto      Thora    Temple
# 5460       Wardrobe Phantom      Thora    Temple
# 5461         Wrong Behavior      Thora    Temple
#
# [5462 rows x 3 columns]

# %%
query = "\
SELECT title, first_name, last_name \
FROM film f, film_actor fa, actor a \
WHERE f.film_id=fa.film_id AND fa.actor_id=a.actor_id"
df = pd.read_sql_query(query,con=engine)
df
# Out:
#                       title first_name last_name
# 0          Academy Dinosaur   Penelope   Guiness
# 1      Anaconda Confessions   Penelope   Guiness
# 2               Angels Life   Penelope   Guiness
# 3     Bulworth Commandments   Penelope   Guiness
# 4             Cheaper Clyde   Penelope   Guiness
# ...                     ...        ...       ...
# 5457       Telegraph Voyage      Thora    Temple
# 5458        Trojan Tomorrow      Thora    Temple
# 5459        Virginian Pluto      Thora    Temple
# 5460       Wardrobe Phantom      Thora    Temple
# 5461         Wrong Behavior      Thora    Temple
#
# [5462 rows x 3 columns]

# %% [markdown]
# ## LEFT JOIN
# With an inner join, we only get the results that are in both tables. But there are other types of joins.
#
# If we want to know which rows in a table don’t have a match in the other table, we use a LEFT JOIN or RIGHT JOIN (depending on which table you want all of the results from).

# %%
query = "\
SELECT f.film_id, title, inventory_id, store_id  \
FROM film f  \
LEFT JOIN inventory i \
ON f.film_id=i.film_id"
df = pd.read_sql_query(query,con=engine)
df
# Out:
#       film_id                title  inventory_id  store_id
# 0           1     Academy Dinosaur           1.0       1.0
# 1           1     Academy Dinosaur           2.0       1.0
# 2           1     Academy Dinosaur           3.0       1.0
# 3           1     Academy Dinosaur           4.0       1.0
# 4           1     Academy Dinosaur           5.0       2.0
# ...       ...                  ...           ...       ...
# 4618       14       Alice Fantasia           NaN       NaN
# 4619      943    Villain Desperate           NaN       NaN
# 4620      874         Tadpole Park           NaN       NaN
# 4621      217           Dazed Punk           NaN       NaN
# 4622      144  Chinatown Gladiator           NaN       NaN
#
# [4623 rows x 4 columns]

# %%
query = "\
SELECT f.film_id, title, inventory_id, store_id \
FROM film f  \
LEFT JOIN inventory i \
ON f.film_id=i.film_id \
WHERE i.film_id IS NULL"
df = pd.read_sql_query(query,con=engine)
df
# Out:
#     film_id                   title inventory_id store_id
# 0        14          Alice Fantasia         None     None
# 1        33             Apollo Teen         None     None
# 2        36          Argonauts Town         None     None
# 3        38           Ark Ridgemont         None     None
# 4        41    Arsenic Independence         None     None
# 5        87       Boondock Ballroom         None     None
# 6       108           Butch Panther         None     None
# 7       128           Catch Amistad         None     None
# 8       144     Chinatown Gladiator         None     None
# 9       148          Chocolate Duck         None     None
# 10      171    Commandments Express         None     None
# 11      192        Crossing Divorce         None     None
# 12      195         Crowds Telemark         None     None
# 13      198        Crystal Breaking         None     None
# 14      217              Dazed Punk         None     None
# 15      221  Deliverance Mulholland         None     None
# 16      318       Firehouse Vietnam         None     None
# 17      325           Floats Garden         None     None
# 18      332   Frankenstein Stranger         None     None
# 19      359      Gladiator Westward         None     None
# 20      386               Gump Date         None     None
# 21      404           Hate Handicap         None     None
# 22      419             Hocus Frida         None     None
# 23      495        Kentuckian Giant         None     None
# 24      497        Kill Brotherhood         None     None
# 25      607             Muppet Mile         None     None
# 26      642          Order Betrayed         None     None
# 27      669           Pearl Destiny         None     None
# 28      671         Perdition Fargo         None     None
# 29      701           Psycho Shrunk         None     None
# 30      712       Raiders Antitrust         None     None
# 31      713           Rainbow Shock         None     None
# 32      742           Roof Champion         None     None
# 33      801           Sister Freddy         None     None
# 34      802             Sky Miracle         None     None
# 35      860        Suicides Silence         None     None
# 36      874            Tadpole Park         None     None
# 37      909        Treasure Command         None     None
# 38      943       Villain Desperate         None     None
# 39      950            Volume House         None     None
# 40      954               Wake Jaws         None     None
# 41      955            Walls Artist         None     None

# %% [markdown]
# # 2. Creating tables, importing, & exporting data
# Let's create a database/schema call `cisc520`.

# %%
engine_cisc520 = create_engine('postgresql://postgres:password@localhost:5432/cisc520')

# %%
create_table = "\
CREATE TABLE student ( \
    id serial PRIMARY KEY, \
    first_name text, \
    last_name text, \
    admission_year smallint \
)"

drop_table = 'DROP TABLE IF EXISTS student'

with engine_cisc520.connect() as conn:
    conn.execute(drop_table)
    conn.execute(create_table)

# %%
query = "SELECT * FROM student"
df = pd.read_sql_query(query,con=engine_cisc520)
df
# Out:
# Empty DataFrame
# Columns: [id, first_name, last_name, admission_year]
# Index: []

# %%
insert_row = "\
INSERT INTO student (first_name, last_name, admission_year) \
VALUES ('Alice', 'Walker', 2017), \
       ('Bob', 'Williams', 2016), \
       ('Charlie', 'Weston', 2016);"

delete_all_rows = "DELETE FROM student"

with engine_cisc520.connect() as conn:
    conn.execute(delete_all_rows)
    conn.execute(insert_row)

# %%
query = "SELECT * FROM student where first_name = 'Alice'"
df = pd.read_sql_query(query,con=engine_cisc520)
df
# Out:
#    id first_name last_name  admission_year
# 0   1      Alice    Walker            2017

# %% [markdown]
# ## Create a temporary table
# When creating a table, you also have the option to make the table temporary – it will be deleted when your database session ends. This is often useful with tables created from select statements, but it can be used with any table creation command.

# %%
create_table = "\
CREATE TABLE a_student AS \
SELECT * FROM student \
WHERE student.first_name = 'Alice'"

drop_table = 'DROP TABLE IF EXISTS a_student'

with engine_cisc520.connect() as conn:
    conn.execute(drop_table)
    conn.execute(create_table)

# %%
query = 'select * from a_student'
df = pd.read_sql_query(query,con=engine_cisc520)
df
# Out:
#    id first_name last_name  admission_year
# 0   1      Alice    Walker            2017

# %%
create_temp_table = "\
CREATE TEMP TABLE b_student AS \
SELECT * FROM student \
WHERE student.first_name = 'Charlie'"

drop_temp_table = "DROP TABLE IF EXISTS b_student"

with engine_cisc520.connect() as conn:
    conn.execute(drop_temp_table)
    conn.execute(create_temp_table)

# %%
query = 'select * from b_student'
df = pd.read_sql_query(query,con=engine_cisc520)
df
# Out:
#    id first_name last_name  admission_year
# 0   3    Charlie    Weston            2016

# %% [markdown]
# ## VIEW:
# Instead of creating a new table (permanent or temporary), you can instead create a view (either permanent or temporary) that is essentially a saved query that you can reference as a table. You can query the view like a table, but the data isn’t copied – it pulls the results from the original tables. So if the original tables are updated, the results of the view will change.

# %%
# Note that we are now using 'dvdrental' database.

create_view = "\
CREATE TEMP VIEW actor_film_names AS \
SELECT title, first_name, last_name \
FROM actor a \
INNER JOIN film_actor fa \
ON a.actor_id=fa.actor_id \
INNER JOIN film f \
ON f.film_id=fa.film_id;"

drop_view = "DROP VIEW IF EXISTS actor_film_names"

with engine.connect() as conn:
    conn.execute(drop_view)
    conn.execute(create_view)

# %%
query = 'select * from actor_film_names'
df = pd.read_sql_query(query,con=engine)
df
# Out:
#                       title first_name last_name
# 0          Academy Dinosaur   Penelope   Guiness
# 1      Anaconda Confessions   Penelope   Guiness
# 2               Angels Life   Penelope   Guiness
# 3     Bulworth Commandments   Penelope   Guiness
# 4             Cheaper Clyde   Penelope   Guiness
# ...                     ...        ...       ...
# 5457       Telegraph Voyage      Thora    Temple
# 5458        Trojan Tomorrow      Thora    Temple
# 5459        Virginian Pluto      Thora    Temple
# 5460       Wardrobe Phantom      Thora    Temple
# 5461         Wrong Behavior      Thora    Temple
#
# [5462 rows x 3 columns]

# %% [markdown]
# # 3. Changing & Deleting Tables

# %% [markdown]
# ## Transaction
# SQL commands are executed immediately, unless you put them in a transaction. With select statements, this doesn’t make much of a difference. But when altering the database, you often want to make sure commands execute correctly before committing the change to the database.

# %%
create_table = "\
CREATE TABLE color ( \
    id serial primary key, \
    name text, \
    hex text);"

drop_table = "DROP TABLE IF EXISTS color"
insert_value = "\
INSERT INTO color (name, hex) \
VALUES ('beige', '#F5F5DC'), ('coral', '#FF7F50'), \
        ('cyan', '#00FFFF'), ('gold', '#FFD700');"

with engine_cisc520.connect() as conn:
    conn.execute(drop_table)
    conn.execute(create_table)
    conn.execute(insert_value)

# %%
query = 'select * from color'
df = pd.read_sql_query(query,con=engine_cisc520)
df
# Out:
#    id   name      hex
# 0   1  beige  #F5F5DC
# 1   2  coral  #FF7F50
# 2   3   cyan  #00FFFF
# 3   4   gold  #FFD700

# %%
transaction = "\
begin; \
ALTER TABLE color ADD COLUMN websafe boolean default true; \
SELECT * FROM color; \
commit;"
with engine_cisc520.connect() as conn:
    conn.execute(transaction)

# %%
query = 'select * from color'
df = pd.read_sql_query(query,con=engine_cisc520)
df
# Out:
#    id   name      hex  websafe
# 0   1  beige  #F5F5DC     True
# 1   2  coral  #FF7F50     True
# 2   3   cyan  #00FFFF     True
# 3   4   gold  #FFD700     True

# %%
# Expect ERROR --> Rolled back so table `color` is NOT DELETED.

transaction = "\
begin;\
DROP TABLE color; \
select * from color; \
commit; \
select * from color;"

with engine_cisc520.connect() as conn:
    conn.execute(transaction)

# %%
transaction = "\
begin; \
DROP TABLE color; \
commit;"


with engine_cisc520.connect() as conn:
    conn.execute(transaction)

# %%
# Expected ERROR since table `color` no longer exists.

query = 'select * from color'
df = pd.read_sql_query(query,con=engine_cisc520)
df

# %% [markdown]
# ## Retry

# %%
# Let's recreate and try again ...
create_table = "\
CREATE TABLE color ( \
    id serial primary key, \
    name text, \
    hex text);"

drop_table = "DROP TABLE IF EXISTS color"
insert_value = "\
INSERT INTO color (name, hex) \
VALUES ('beige', '#F5F5DC'), ('coral', '#FF7F50'), \
        ('cyan', '#00FFFF'), ('gold', '#FFD700');"

with engine_cisc520.connect() as conn:
    conn.execute(drop_table)
    conn.execute(create_table)
    conn.execute(insert_value)

# %%
query = "\
select column_name, data_type, character_maximum_length \
from INFORMATION_SCHEMA.COLUMNS \
where table_name = 'color';"
df = pd.read_sql_query(query,con=engine_cisc520)
df
# Out:
#   column_name data_type character_maximum_length
# 0          id   integer                     None
# 1        name      text                     None
# 2         hex      text                     None

# %%
query = 'select * from color'
df = pd.read_sql_query(query,con=engine_cisc520)
df
# Out:
#    id   name      hex
# 0   1  beige  #F5F5DC
# 1   2  coral  #FF7F50
# 2   3   cyan  #00FFFF
# 3   4   gold  #FFD700

# %%
transaction = "\
begin; \
ALTER TABLE color RENAME hex TO webcolor; \
SELECT * FROM color; \
commit;"
with engine_cisc520.connect() as conn:
    conn.execute(transaction)

# %%
query = 'select * from color'
df = pd.read_sql_query(query,con=engine_cisc520)
df
# Out:
#    id   name webcolor
# 0   1  beige  #F5F5DC
# 1   2  coral  #FF7F50
# 2   3   cyan  #00FFFF
# 3   4   gold  #FFD700

# %%
transaction = "\
begin; \
ALTER TABLE color ALTER webcolor TYPE char(7); \
SELECT * FROM color; \
commit"

with engine_cisc520.connect() as conn:
    conn.execute(transaction)

# %%
query = 'select * from color'
df = pd.read_sql_query(query,con=engine_cisc520)
df
# Out:
#    id   name webcolor
# 0   1  beige  #F5F5DC
# 1   2  coral  #FF7F50
# 2   3   cyan  #00FFFF
# 3   4   gold  #FFD700

# %%
query = "\
select column_name, data_type, character_maximum_length \
from INFORMATION_SCHEMA.COLUMNS \
where table_name = 'color';"
df = pd.read_sql_query(query,con=engine_cisc520)
df
# Out:
#   column_name  data_type  character_maximum_length
# 0          id    integer                       NaN
# 1        name       text                       NaN
# 2    webcolor  character                       7.0

# %% [markdown]
# ## Alter table

# %%
create_table = "\
CREATE TABLE food ( \
    id serial primary key, \
    name text not null, \
    type text, \
    favorite boolean default false \
);"

drop_table = 'DROP TABLE IF EXISTS food'

insert_value = "\
INSERT INTO food (name, type) \
VALUES ('broccoli','vegetable'),  \
    ('lime', 'fruit'),  \
    ('green beans', 'vegetable'), \
    ('milk', 'dairy'), \
    ('yogurt', 'dairy'), \
    ('banana', 'fruit'), \
    ('lemon', 'fruit'), \
    ('tortilla', 'carbohydrate'), \
    ('rice', 'carbohydrate');"

with engine_cisc520.connect() as conn:
    conn.execute(drop_table)
    conn.execute(create_table)
    conn.execute(insert_value)

# %%
query = 'select * from food'
df = pd.read_sql_query(query,con=engine_cisc520)
df
# Out:
#    id         name          type  favorite
# 0   1     broccoli     vegetable     False
# 1   2         lime         fruit     False
# 2   3  green beans     vegetable     False
# 3   4         milk         dairy     False
# 4   5       yogurt         dairy     False
# 5   6       banana         fruit     False
# 6   7        lemon         fruit     False
# 7   8     tortilla  carbohydrate     False
# 8   9         rice  carbohydrate     False

# %%
## Changing & Deleting ROWS in table

# %%
create_table = "\
CREATE TABLE workshop ( \
    id serial primary key, \
    name text not null, \
    date date, \
    beginner boolean default false \
);"

drop_table = "DROP TABLE IF EXISTS workshop"

insert_value = "\
INSERT INTO workshop (name, date) \
VALUES ('Intro to Python', '2017-07-10'),  \
        ('Python Data Analysis', '2017-08-03'), \
        ('Databases', '2017-08-17'), \
        ('Intro to R', '2017-09-07');"

with engine_cisc520.connect() as conn:
    conn.execute(drop_table)
    conn.execute(create_table)
    conn.execute(insert_value)

# %%
query = 'select * from workshop'
df = pd.read_sql_query(query,con=engine_cisc520)
df
# Out:
#    id                  name        date  beginner
# 0   1       Intro to Python  2017-07-10     False
# 1   2  Python Data Analysis  2017-08-03     False
# 2   3             Databases  2017-08-17     False
# 3   4            Intro to R  2017-09-07     False

# %%
update_table = "UPDATE workshop SET beginner='t' WHERE id=2;"
with engine_cisc520.connect() as conn:
    conn.execute(update_table)

# %%
query = 'select * from workshop'
df = pd.read_sql_query(query,con=engine_cisc520)
df
# Out:
#    id                  name        date  beginner
# 0   1       Intro to Python  2017-07-10     False
# 1   3             Databases  2017-08-17     False
# 2   4            Intro to R  2017-09-07     False
# 3   2  Python Data Analysis  2017-08-03      True

# %%
update_table = "\
UPDATE workshop \
SET name='Introduction to R', beginner='t' \
WHERE id=4;"
with engine_cisc520.connect() as conn:
    conn.execute(update_table)

# %%
query = 'select * from workshop'
df = pd.read_sql_query(query,con=engine_cisc520)
df
# Out:
#    id                  name        date  beginner
# 0   1       Intro to Python  2017-07-10     False
# 1   3             Databases  2017-08-17     False
# 2   2  Python Data Analysis  2017-08-03      True
# 3   4     Introduction to R  2017-09-07      True

# %% [markdown]
# ## Update with JOIN

# %%
create_table = "\
CREATE TABLE product_segment (\
    ID SERIAL PRIMARY KEY, \
    segment VARCHAR NOT NULL, \
    discount NUMERIC (4, 2) \
);"

drop_table = "DROP TABLE IF EXISTS product_segment"
drop_table_product = "DROP TABLE IF EXISTS product"
 
insert_value = "\
INSERT INTO product_segment (segment, discount) \
VALUES \
    ('Grand Luxury', 0.05), \
    ('Luxury', 0.06), \
    ('Mass', 0.1);"

with engine_cisc520.connect() as conn:
    conn.execute(drop_table_product)
    conn.execute(drop_table)
    conn.execute(create_table)
    conn.execute(insert_value)

# %%
create_table = "\
CREATE TABLE product( \
    id serial primary key, \
    name varchar not null, \
    price numeric(10,2), \
    net_price numeric(10,2), \
    segment_id int not null, \
    foreign key(segment_id) references product_segment(id) \
);"

drop_table = "DROP TABLE IF EXISTS product"

insert_value = "\
INSERT INTO product (name, price, segment_id) \
VALUES ('diam', 804.89, 1), \
    ('vestibulum aliquet', 228.55, 3), \
    ('lacinia erat', 366.45, 2), \
    ('scelerisque quam turpis', 145.33, 3), \
    ('justo lacinia', 551.77, 2), \
    ('ultrices mattis odio', 261.58, 3), \
    ('hendrerit', 519.62, 2), \
    ('in hac habitasse', 843.31, 1), \
    ('orci eget orci', 254.18, 3), \
    ('pellentesque', 427.78, 2), \
    ('sit amet nunc', 936.29, 1), \
    ('sed vestibulum', 910.34, 1), \
    ('turpis eget', 208.33, 3), \
    ('cursus vestibulum', 985.45, 1), \
    ('orci nullam', 841.26, 1), \
    ('est quam pharetra', 896.38, 1), \
    ('posuere', 575.74, 2), \
    ('ligula', 530.64, 2), \
    ('convallis', 892.43, 1), \
    ('nulla elit ac', 161.71, 3);"
with engine_cisc520.connect() as conn:
    conn.execute(drop_table)
    conn.execute(create_table)
    conn.execute(insert_value)

# %%
query = 'select * from product_segment'
df = pd.read_sql_query(query,con=engine_cisc520)
df
# Out:
#    id       segment  discount
# 0   1  Grand Luxury      0.05
# 1   2        Luxury      0.06
# 2   3          Mass      0.10

# %%
query = 'select * from product'
df = pd.read_sql_query(query,con=engine_cisc520)
df
# Out:
#     id                     name   price net_price  segment_id
# 0    1                     diam  804.89      None           1
# 1    2       vestibulum aliquet  228.55      None           3
# 2    3             lacinia erat  366.45      None           2
# 3    4  scelerisque quam turpis  145.33      None           3
# 4    5            justo lacinia  551.77      None           2
# 5    6     ultrices mattis odio  261.58      None           3
# 6    7                hendrerit  519.62      None           2
# 7    8         in hac habitasse  843.31      None           1
# 8    9           orci eget orci  254.18      None           3
# 9   10             pellentesque  427.78      None           2
# 10  11            sit amet nunc  936.29      None           1
# 11  12           sed vestibulum  910.34      None           1
# 12  13              turpis eget  208.33      None           3
# 13  14        cursus vestibulum  985.45      None           1
# 14  15              orci nullam  841.26      None           1
# 15  16        est quam pharetra  896.38      None           1
# 16  17                  posuere  575.74      None           2
# 17  18                   ligula  530.64      None           2
# 18  19                convallis  892.43      None           1
# 19  20            nulla elit ac  161.71      None           3

# %%
query = "\
SELECT *  \
FROM product \
LEFT JOIN product_segment \
ON product.segment_id=product_segment.id;"

df = pd.read_sql_query(query,con=engine_cisc520)
df
# Out:
#     id                     name   price net_price  segment_id  id  \
# 0    1                     diam  804.89      None           1   1
# 1    2       vestibulum aliquet  228.55      None           3   3
# 2    3             lacinia erat  366.45      None           2   2
# 3    4  scelerisque quam turpis  145.33      None           3   3
# 4    5            justo lacinia  551.77      None           2   2
# 5    6     ultrices mattis odio  261.58      None           3   3
# 6    7                hendrerit  519.62      None           2   2
# 7    8         in hac habitasse  843.31      None           1   1
# 8    9           orci eget orci  254.18      None           3   3
# 9   10             pellentesque  427.78      None           2   2
# 10  11            sit amet nunc  936.29      None           1   1
# 11  12           sed vestibulum  910.34      None           1   1
# 12  13              turpis eget  208.33      None           3   3
# 13  14        cursus vestibulum  985.45      None           1   1
# 14  15              orci nullam  841.26      None           1   1
# 15  16        est quam pharetra  896.38      None           1   1
# 16  17                  posuere  575.74      None           2   2
# 17  18                   ligula  530.64      None           2   2
# 18  19                convallis  892.43      None           1   1
# 19  20            nulla elit ac  161.71      None           3   3
#
#          segment  discount
# 0   Grand Luxury      0.05
# 1           Mass      0.10
# 2         Luxury      0.06
# 3           Mass      0.10
# 4         Luxury      0.06
# 5           Mass      0.10
# 6         Luxury      0.06
# 7   Grand Luxury      0.05
# 8           Mass      0.10
# 9         Luxury      0.06
# 10  Grand Luxury      0.05
# 11  Grand Luxury      0.05
# 12          Mass      0.10
# 13  Grand Luxury      0.05
# 14  Grand Luxury      0.05
# 15  Grand Luxury      0.05
# 16        Luxury      0.06
# 17        Luxury      0.06
# 18  Grand Luxury      0.05
# 19          Mass      0.10

# %%
update_product = "\
UPDATE product \
SET net_price = price - price * discount \
FROM product_segment \
WHERE product.segment_id = product_segment.id;"
with engine_cisc520.connect() as conn:
    conn.execute(update_product)

# %%
query = 'select * from product'
df = pd.read_sql_query(query,con=engine_cisc520)
df
# Out:
# Empty DataFrame
# Columns: [id, name, price, net_price, segment_id]
# Index: []

# %% [markdown]
# ## DELETE
# We can also delete rows. If you neglect to add a where clause or mis-specify it, you can delete everything in your table. So remember to use transactions.

# %%
transaction = "\
begin;\
DELETE FROM workshop WHERE id=4;\
commit;"

with engine_cisc520.connect() as conn:
    conn.execute(transaction)

# %%
query = 'select * from workshop'
df = pd.read_sql_query(query,con=engine_cisc520)
df
# Out:
#    id                  name        date  beginner
# 0   1       Intro to Python  2017-07-10     False
# 1   3             Databases  2017-08-17     False
# 2   2  Python Data Analysis  2017-08-03      True

# %%
delete_row = "\
DELETE FROM product \
WHERE segment_id IN  \
(SELECT id  \
 FROM product_segment \
 WHERE discount < .06);"

with engine_cisc520.connect() as conn:
    conn.execute(delete_row)

# %%
query = 'select * from product'
df = pd.read_sql_query(query,con=engine_cisc520)
df
# Out:
#     id                     name   price net_price  segment_id
# 0    2       vestibulum aliquet  228.55      None           3
# 1    3             lacinia erat  366.45      None           2
# 2    4  scelerisque quam turpis  145.33      None           3
# 3    5            justo lacinia  551.77      None           2
# 4    6     ultrices mattis odio  261.58      None           3
# 5    7                hendrerit  519.62      None           2
# 6    9           orci eget orci  254.18      None           3
# 7   10             pellentesque  427.78      None           2
# 8   13              turpis eget  208.33      None           3
# 9   17                  posuere  575.74      None           2
# 10  18                   ligula  530.64      None           2
# 11  20            nulla elit ac  161.71      None           3

# %%
query = '\
SELECT id  \
FROM product_segment \
WHERE discount < .06'
df = pd.read_sql_query(query,con=engine_cisc520)
df
# Out:
#    id
# 0   1

# %% [markdown]
# # 4. Advanced Queries
# The following contains `advanced queries` on dvdrental database.
#
# ## Query 1:
# What are the top/least rented(demanded) genres and what are what are their total sales?
#
# Based on this website: `https://github.com/anitaokoh/DVD-RENTAL`

# %%
#  Question 1: What are the top/least rented(demanded) genres and what are what are their total sales?
query = '\
WITH t1 AS (SELECT c.name AS Genre, count(cu.customer_id) AS Total_rent_demand \
            FROM category c \
            JOIN film_category fc \
            USING(category_id) \
            JOIN film f \
            USING(film_id) \
            JOIN inventory i \
            USING(film_id) \
            JOIN rental r \
            USING(inventory_id) \
            JOIN customer cu \
            USING(customer_id) \
            GROUP BY 1 \
            ORDER BY 2 DESC), \
     t2 AS (SELECT c.name AS Genre, SUM(p.amount) AS total_sales \
            FROM category c \
            JOIN film_category fc \
            USING(category_id) \
            JOIN film f \
            USING(film_id) \
            JOIN inventory i \
            USING(film_id) \
            JOIN rental r \
            USING(inventory_id) \
            JOIN payment p \
            USING(rental_id) \
            GROUP BY 1 \
            ORDER BY 2 DESC) \
SELECT t1.genre, t1.total_rent_demand, t2.total_sales \
FROM t1 \
JOIN t2 \
ON t1.genre = t2.genre;'

# %%
df = pd.read_sql_query(query,con=engine)
df
# Out:
#           genre  total_rent_demand  total_sales
# 0        Sports               1179      4892.19
# 1     Animation               1166      4245.31
# 2        Action               1112      3951.84
# 3        Sci-Fi               1101      4336.01
# 4        Family               1096      3830.15
# 5         Drama               1060      4118.46
# 6   Documentary               1050      3749.65
# 7       Foreign               1033      3934.47
# 8         Games                969      3922.18
# 9      Children                945      3309.39
# 10       Comedy                941      4002.48
# 11          New                940      3966.38
# 12     Classics                939      3353.38
# 13       Horror                846      3401.27
# 14       Travel                837      3227.36
# 15        Music                830      3071.52

# %% [markdown]
# ## Query 2:
# Question 2: Can we know how many distinct users have rented each genre?

# %%
query = '\
SELECT c.name AS Genre, count(DISTINCT cu.customer_id) AS Total_rent_demand \
FROM category c \
JOIN film_category fc \
USING(category_id) \
JOIN film f \
USING(film_id) \
JOIN inventory i \
USING(film_id) \
JOIN rental r \
USING(inventory_id) \
JOIN customer cu \
USING(customer_id) \
GROUP BY 1 \
ORDER BY 2 DESC;'

# %%
df = pd.read_sql_query(query,con=engine)
df
# Out:
#           genre  total_rent_demand
# 0        Sports                519
# 1        Action                510
# 2        Sci-Fi                507
# 3        Family                501
# 4         Drama                501
# 5     Animation                500
# 6        Comedy                495
# 7       Foreign                493
# 8   Documentary                483
# 9      Children                482
# 10        Games                474
# 11          New                468
# 12     Classics                468
# 13       Horror                451
# 14        Music                447
# 15       Travel                442

# %% [markdown]
# ### Query 3:
# What is the Average rental rate for each genre? (from the highest to the lowest)

# %%
query = '\
SELECT c.name AS genre, ROUND(AVG(f.rental_rate),2) AS Average_rental_rate \
FROM category c \
JOIN film_category fc \
USING(category_id) \
JOIN film f \
USING(film_id) \
GROUP BY 1 \
ORDER BY 2 DESC;'

# %%
df = pd.read_sql_query(query,con=engine)
df
# Out:
#           genre  average_rental_rate
# 0         Games                 3.25
# 1        Travel                 3.24
# 2        Sci-Fi                 3.22
# 3        Comedy                 3.16
# 4        Sports                 3.13
# 5           New                 3.12
# 6       Foreign                 3.10
# 7        Horror                 3.03
# 8         Drama                 3.02
# 9         Music                 2.95
# 10     Children                 2.89
# 11    Animation                 2.81
# 12       Family                 2.76
# 13     Classics                 2.74
# 14  Documentary                 2.67
# 15       Action                 2.65

# %% [markdown]
# ### Query #4:
# How many rented films were returned late, early and on time?

# %%
query = "\
WITH t1 AS (Select *, DATE_PART('day', return_date - rental_date) AS date_difference \
            FROM rental), \
t2 AS (SELECT rental_duration, date_difference, \
              CASE \
                WHEN rental_duration > date_difference THEN 'Returned early' \
                WHEN rental_duration = date_difference THEN 'Returned on Time' \
                ELSE 'Returned late' \
              END AS Return_Status \
          FROM film f \
          JOIN inventory i \
          USING(film_id) \
          JOIN t1 \
          USING (inventory_id)) \
SELECT Return_status, count(*) As total_no_of_films \
FROM t2 \
GROUP BY 1 \
ORDER BY 2 DESC;"

# %%
df = pd.read_sql_query(query,con=engine)
df
# Out:
#       return_status  total_no_of_films
# 0    Returned early               7738
# 1     Returned late               6586
# 2  Returned on Time               1720

# %% [markdown]
# ### Query #5:
# In which countries does Rent A Film have a presence in and what is the customer base in each country? What are the total sales in each country? (From most to least)

# %%
query = "\
SELECT country, count(DISTINCT customer_id) AS customer_base, SUM(amount) AS total_sales \
FROM country \
JOIN city \
USING(country_id) \
JOIN address \
USING(city_id) \
JOIN customer \
USING (address_id) \
JOIN payment \
USING(customer_id) \
GROUP BY 1 \
ORDER BY 2 DESC;"

# %%
df = pd.read_sql_query(query,con=engine)
df
# Out:
#                   country  customer_base  total_sales
# 0                   India             60      6034.78
# 1                   China             53      5251.03
# 2           United States             36      3685.31
# 3                   Japan             31      3122.51
# 4                  Mexico             30      2984.82
# ..                    ...            ...          ...
# 103               Tunisia              1        73.78
# 104          Turkmenistan              1       126.74
# 105                Tuvalu              1        93.78
# 106  Virgin Islands, U.S.              1       121.69
# 107           Afghanistan              1        67.82
#
# [108 rows x 3 columns]

# %% [markdown]
# ### Query #6:
# Who are the top 5 customers per total sales and can we get their detail just in case Rent A Film want to reward them?

# %%
query = "\
WITH t1 AS (SELECT *, first_name || ' ' || last_name AS full_name \
            FROM customer) \
SELECT full_name, email, address, phone, city, country, sum(amount) AS total_purchase_in_currency \
FROM t1 \
JOIN address \
USING(address_id) \
JOIN city \
USING (city_id) \
JOIN country \
USING (country_id) \
JOIN payment \
USING(customer_id) \
GROUP BY 1,2,3,4,5,6 \
ORDER BY 7 DESC \
LIMIT 5;"

# %%
df = pd.read_sql_query(query,con=engine)
df
# Out:
#         full_name                              email                address  \
# 0    Eleanor Hunt    eleanor.hunt@sakilacustomer.org         1952 Pune Lane
# 1       Karl Seal       karl.seal@sakilacustomer.org       1427 Tabuk Place
# 2   Marion Snyder   marion.snyder@sakilacustomer.org  1891 Rizhao Boulevard
# 3  Rhonda Kennedy  rhonda.kennedy@sakilacustomer.org      1749 Daxian Place
# 4      Clara Shaw      clara.shaw@sakilacustomer.org    1027 Songkhla Manor
#
#           phone                 city        country  \
# 0  354615066969          Saint-Denis         Runion
# 1  214756839122           Cape Coral  United States
# 2  391065549876  Santa Brbara dOeste         Brazil
# 3  963369996279            Apeldoorn    Netherlands
# 4  563660187896            Molodetno        Belarus
#
#    total_purchase_in_currency
# 0                      211.55
# 1                      208.58
# 2                      194.61
# 3                      191.62
# 4                      189.60
